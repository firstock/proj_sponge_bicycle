# %% [markdown]
# ### seoul_population

# %%
import pandas as pd
from pandas import DataFrame

# %%
df= pd.read_csv('data/seoul_population.csv', encoding="cp949", skiprows= [1])

# %%
df= df[df.iloc[:,0]!='서울특별시']

# %%
df1= df.T

# %%
df1.columns= df1.iloc[0]

# %%
df1= df1.iloc[1:,:]

# %%
df1.columns.name='지역구'

# %%
f= lambda x: str.replace(x, '. ','-')

# %%
df1.index= df1.index.map(f)

# %%
col1= df1.columns
col2= df1.iloc[0]

# %%
# col1= df1.columns.unique(); col1
# col2= df1.iloc[0].unique()

# %%
index1= df1.index[1:]

# %%
val= df1.iloc[1:,:]

# %%
# print(df1.columns.unique())
# df1.columns.value_counts()

# %%
df_mul= DataFrame(val, columns= ([list(col1), list(col2)]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-176-7f782120a7aa> in <module>()
# ----> 1 df_mul= DataFrame(val, columns= ([list(col1), list(col2)]))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     271         if isinstance(data, BlockManager):
#     272             mgr = self._init_mgr(data, axes=dict(index=index, columns=columns),
# --> 273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
#     275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _init_mgr(self, mgr, axes, dtype, copy)
#     163                 mgr = mgr.reindex_axis(axe,
#     164                                        axis=self._get_block_manager_axis(a),
# ...

# %%
df_mul
# Out:
# 지역구           종로구  종로구  종로구  종로구  종로구  종로구  종로구  종로구  종로구  종로구 ...   강동구  강동구  \
# 지역구 5세별                                                        ...
# 종로구 10 - 14세  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
#     15 - 19세  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
#     20 - 24세  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
#     25 - 29세  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
#     30 - 34세  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
#     35 - 39세  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
#     40 - 44세  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
#     45 - 49세  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
#     50 - 54세  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
#     55 - 59세  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN
# ...

# %%
df1
# Out:
# 지역구           종로구       종로구       종로구       종로구       종로구       종로구       종로구  \
# 5세별      10 - 14세  15 - 19세  20 - 24세  25 - 29세  30 - 34세  35 - 39세  40 - 44세
# 2016-01      5874      8504     11428     11877     11352     10427     12700
# 2016-02      5833      8433     11462     11894     11326     10502     12588
# 2016-03      5779      8724     11666     11932     11219     10460     12395
# 2016-04      5707      8635     11659     11973     11171     10475     12302
# 2016-05      5643      8542     11657     11967     11100     10477     12152
# 2016-06      5626      8446     11601     11931     11067     10503     12085
# 2016-07      5620      8350     11533     11945     11000     10558     11992
# 2016-08      5561      8286     11560     11926     10969     10503     11883
# 2016-09      5525      8336     11561     11931     10877     10507     11841
# 2016-10      5510      8248     11537     11982     10807     10486     11770
# ...

# %%
# df1.to_csv('data_join/seoulPopulation_clean.csv', encoding='ANSI')
